# %% [markdown]
# # ***Multiple linear regression**

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('multiple_regression.csv')
df
# Out:
#    Study_Hours  Sleep_Hours  Exam_Score
# 0          2.0          6.0          65
# 1          3.5          7.0          78
# 2          1.5          5.5          55
# 3          4.0          8.0          85
# 4          3.0          6.5          72
# 5          5.5          7.5          90
# 6          6.0          8.5          95
# 7          2.5          6.0          68
# 8          4.5          7.0          88
# 9          5.0          7.5          92

# %%
df.shape
# Out:
# (10, 3)

# %%
df.isnull().sum()
# Out:
# Study_Hours    0
# Sleep_Hours    0
# Exam_Score     0
# dtype: int64

# %%
sns.pairplot(data=df)

# %% [markdown]
# * if our data is more or very wide then we use__

# %%
sns.heatmap(data=df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# * here we can see this haetmap, Two data sets that have linearity will have a high correlation.

# %%
x = df.iloc[:,:-1]
y = df['Exam_Score']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
lr =LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.4481560766718964

# %% [markdown]
# * here our data is very less  information thats reason  accuracy are very very low but this process are good.

# %% [markdown]
# * and simple linear regression has y = mx + c  this equation solveing process.
