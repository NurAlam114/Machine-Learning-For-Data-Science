# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('unlevel_iris.csv')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
sns.pairplot(data=df)

# %% [markdown]
# * now we create dendogram

# %%
import scipy.cluster.hierarchy as sc

# %%
sc.dendrogram(sc.linkage(df,
    method = 'single',
    metric = 'euclidean',))
# Out:
# {'icoord': [[85.0, 85.0, 95.0, 95.0],
#   [145.0, 145.0, 155.0, 155.0],
#   [135.0, 135.0, 150.0, 150.0],
#   [205.0, 205.0, 215.0, 215.0],
#   [195.0, 195.0, 210.0, 210.0],
#   [225.0, 225.0, 235.0, 235.0],
#   [255.0, 255.0, 265.0, 265.0],
#   [245.0, 245.0, 260.0, 260.0],
#   [285.0, 285.0, 295.0, 295.0],
#   [275.0, 275.0, 290.0, 290.0],
#   [252.5, 252.5, 282.5, 282.5],
#   [230.0, 230.0, 267.5, 267.5],
#   [202.5, 202.5, 248.75, 248.75],
#   [185.0, 185.0, 225.625, 225.625],
#   [315.0, 315.0, 325.0, 325.0],
#   [305.0, 305.0, 320.0, 320.0],
#   [205.3125, 205.3125, 312.5, 312.5],
#   [175.0, 175.0, 258.90625, 258.90625],
#   [165.0, 165.0, 216.953125, 216.953125],
#   [335.0, 335.0, 345.0, 345.0],
#   [375.0, 375.0, 385.0, 385.0],
#   [415.0, 415.0, 425.0, 425.0],
#   [405.0, 405.0, 420.0, 420.0],
#   [395.0, 395.0, 412.5, 412.5],
#   [380.0, 380.0, 403.75, 403.75],
#   [365.0, 365.0, 391.875, 391.875],
#   [435.0, 435.0, 445.0, 445.0],
#   [378.4375, 378.4375, 440.0, 440.0],
# ...

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
ac = AgglomerativeClustering(n_clusters=2,linkage='single')
df['predict'] = ac.fit_predict(df)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  predict
# 0           5.1          3.5           1.4          0.2        1
# 1           4.9          3.0           1.4          0.2        1
# 2           4.7          3.2           1.3          0.2        1
# 3           4.6          3.1           1.5          0.2        1
# 4           5.0          3.6           1.4          0.2        1

# %%
sns.pairplot(data=df,hue='predict')

# %% [markdown]
# * we know iris dataset has 3 cluster bur=t here we3 can see 2 cluster from dendogram.actualy Agglomerative Hierarchical ar cluster define dependent of distance.
