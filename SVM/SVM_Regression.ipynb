# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('placement.csv')
df.head()
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                  26.0       1
# 1  7.46                  38.0       1
# 2  7.54                  40.0       1
# 3  6.42                   8.0       1
# 4  7.23                  17.0       0

# %%
sns.scatterplot(x='cgpa',y ='placement_exam_marks',data =df,hue='placed')
# Out:
# <Axes: xlabel='cgpa', ylabel='placement_exam_marks'>

# %%
x = df[["cgpa"]]
y = df['placed']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.svm import SVR

# %%
sv = SVR(kernel='rbf')
sv.fit(x_train,y_train)
# Out:
# SVR()

# %%
sv.score(x_test,y_test) *100
# Out:
# -29.32886379349855

# %%
sv.score(x_train,y_train) *100
# Out:
# -24.2174095611041

# %%
sns.scatterplot(x='cgpa',y ='placement_exam_marks',data =df,hue='placed')
plt.plot(df['cgpa'],sv.predict(x),color ="red")

# %% [markdown]
# * here this is the rules of svm regression method. accuracy is wrong reson of our dataset is not perfect.
