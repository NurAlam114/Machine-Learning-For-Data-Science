# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("multiple_linear_regression_dataset.csv")
df.head(5)
# Out:
#    age  experience  income
# 0   25           1   30450
# 1   30           3   35670
# 2   47           2   31580
# 3   32           5   40130
# 4   43          10   47830

# %%
df.isnull().sum()
# Out:
# age           0
# experience    0
# income        0
# dtype: int64

# %%
df.shape
# Out:
# (20, 3)

# %%
sns.pairplot(data=df)

# %% [markdown]
# * decition tree

# %%
x = df.iloc[:,:-1]
y = df["income"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor,plot_tree

# %%
dt = DecisionTreeRegressor()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dt.score(x_test,y_test)*100
# Out:
# 29.782687463379354

# %% [markdown]
# * here Accuracy is very less, becouse of dataset

# %%
plot_tree(dt)
plt.show()

# %% [markdown]
# * our model overfitting or not check

# %%
dt.score(x_train,y_train)*100
# Out:
# 100.0

# %% [markdown]
# * here if we can see 100 then its not overfitting.it will be  overfitting  when its value is greater than 100.
